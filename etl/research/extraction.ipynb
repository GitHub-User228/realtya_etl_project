# %%
from etl.parser import RealtyYaParser

# %%
parser = RealtyYaParser()
df = parser.retrieve(return_data=True, save_data=True)
# Out:
# [2024-07-14 20:48:40,706: 48: logger: INFO: utils:  yaml file: /home/etl_project/src/etl/config.yaml loaded successfully]
# [2024-07-14 20:48:40,707: 123: logger: INFO: parser:  STARTING PARSING STAGE]
#   0%|          | 0/25 [00:00<?, ?it/s]
# [2024-07-14 21:02:13,183: 170: logger: INFO: parser:  Number of parsed observations: 648]
# [2024-07-14 21:02:13,185: 171: logger: INFO: parser:  Number of skipped pages: 0]
# [2024-07-14 21:02:13,185: 172: logger: INFO: parser:  Number of viewed pages: 25]
# [2024-07-14 21:02:13,414: 218: logger: INFO: utils:  Table realty has been appended to the existing table to the source database]
# [2024-07-14 21:02:13,415: 189: logger: INFO: parser:  ENDING PARSING STAGE]

# %%
df
# Out:
#                         flat_type  \
# 0     43 м², 2-комнатная квартира
# 1     61 м², 3-комнатная квартира
# 2       27 м², апартаменты-студия
# 3       24 м², апартаменты-студия
# 4     29 м², 1-комнатная квартира
# ..                            ...
# 643   72 м², 1-комнатная квартира
# 644   57 м², 3-комнатная квартира
# 645   69 м², 4-комнатная квартира
# 646     16 м², апартаменты-студия
# 647  124 м², 3-комнатная квартира
#
#                                              main_info  \
# 0    [43 м²общая, 1 этажиз 5, 2,5 мпотолки, 1963 го...
# 1    [61 м²общая, 3 этажиз 9, 2,5 мпотолки, 1972 го...
# 2    [27 м²общая, 24 м²жилая, 5 этажиз 12, 2,7 мпот...
# 3    [24 м²общая, 25 этажиз 26, 2022 годгод постройки]
# 4    [29 м²общая, 4 этажиз 9, 2,5 мпотолки, 1968 го...
# ..                                                 ...
# 643   [72 м²общая, 18 м²жилая, 32 м²кухня, 4 этажиз 5]
# 644  [57 м²общая, 40 м²жилая, 7 м²кухня, 8 этажиз 9...
# 645  [69 м²общая, 47 м²жилая, 7 м²кухня, 1 этажиз 9...
# 646    [16 м²общая, 1 этажиз 4, 1891 годгод постройки]
# 647  [124 м²общая, 58 м²жилая, 18 м²кухня, 5 этажиз...
#
#                                               fee_info  \
# 0                 [0 ₽, 0 ₽, вся квитанция, 43 000 ₽ ]
# 1                 [0 ₽, 0 ₽, вся квитанция, 73 000 ₽ ]
# 2            [30 000 ₽, 0 ₽, вся квитанция, 80 000 ₽ ]
# 3                 [0 ₽, 0 ₽, вся квитанция, 35 500 ₽ ]
# 4                 [0 ₽, 0 ₽, вся квитанция, 29 000 ₽ ]
# ..                                                 ...
# 643  [есть, 84 000 ₽, вся квитанция, 204 000 ₽ + за...
# 644       [есть, 0 ₽, вся квитанция, 55 000 ₽ + залог]
# 645    [75 000 ₽, 37 500 ₽, вся квитанция, 187 500 ₽ ]
# 646          [30 000 ₽, 0 ₽, вся квитанция, 61 500 ₽ ]
# 647  [есть, 65 000 ₽, включены в стоимость, 195 000...
#
#                                           address_info  \
# 0               Санкт-Петербург, Дрезденская улица, 24
# 1                Санкт-Петербург, Наличная улица, 45к1
# 2    Санкт-Петербург, дорога на Турухтанные Острова...
# 3             Санкт-Петербург, улица Орджоникидзе, 44А
# 4                  Санкт-Петербург, Народная улица, 16
# ..                                                 ...
# 643            Санкт-Петербург, Малая Морская улица, 6
# 644                 Санкт-Петербург, проспект КИМа, 4Б
# 645           Санкт-Петербург, Белградская улица, 34к1
# 646          Санкт-Петербург, Суворовский проспект, 39
# 647              Санкт-Петербург, улица Рубинштейна, 3
#
#                                         extra_features             offer_id  \
# 0    [Отделка — косметический ремонт, Санузел совме...  4589075103721385067
# 1    [Отделка — косметический ремонт, Санузел разде...  2501820982645087480
# 2    [Отделка — дизайнерский ремонт, Санузел совмещ...  8540862769695746817
# 3    [Отделка — евроремонт, Санузел совмещённый, Ви...  3103029245287252382
# 4    [Отделка — косметический ремонт, Санузел совме...  8326293742460757901
# ..                                                 ...                  ...
# 643  [18 м², Отделка — евроремонт, Вид из окон во д...  4471907011169517020
# 644  [20 м² 12 м² 8 м², Вид из окон на улицу, Мебел...  4471907011169546655
# 645  [10 м² 10 м² 10 м² 17 м², Отделка — требуется ...  3514492942855114496
# 646  [Отделка — дизайнерский ремонт, Санузел совмещ...   897016339333878546
# 647  [20 м² 20 м² 18 м², Отделка — евроремонт, Вид ...  4471907011169542942
#
#     date_parsed
# 0    2024-07-14
# 1    2024-07-14
# 2    2024-07-14
# 3    2024-07-14
# 4    2024-07-14
# ..          ...
# 643  2024-07-14
# 644  2024-07-14
# 645  2024-07-14
# 646  2024-07-14
# 647  2024-07-14
#
# [526 rows x 7 columns]
